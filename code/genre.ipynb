# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# get the metadata for 
df = pd.read_csv("../data/network_metadata_with_genres.csv")

# %%
df

# %%
G = nx.read_gexf("../data/gexf/1.gexf", node_type=None, relabel=False, version='1.2draft')

# %%
nx.draw(G)
